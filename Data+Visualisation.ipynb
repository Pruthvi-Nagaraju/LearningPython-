# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
from scipy import stats # for stats

# %%
#plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# allows plots to be seen in the ipy notebook
# %matplotlib inline

# %%
data1= randn(100)

# %%
plt.hist(data1)
# Out:
# (array([  1.,   5.,  14.,  11.,  24.,  21.,  16.,   3.,   2.,   3.]),
#  array([-2.67222422, -2.0668468 , -1.46146938, -0.85609196, -0.25071454,
#          0.35466288,  0.9600403 ,  1.56541772,  2.17079514,  2.77617257,
#          3.38154999]),
#  <a list of 10 Patch objects>)

# %%
data2= randn(80)
plt.hist(data2, color='indianred')
# Out:
# (array([  2.,   0.,   4.,  14.,  19.,   9.,  15.,   6.,   7.,   4.]),
#  array([-2.81733275, -2.30307509, -1.78881743, -1.27455977, -0.76030211,
#         -0.24604446,  0.2682132 ,  0.78247086,  1.29672852,  1.81098618,
#          2.32524384]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data1, normed=True, color='indianred', alpha= 0.5, bins=20)
plt.hist(data2, normed=True,  alpha= 0.5, bins=20)
# Out:
# (array([ 0.09722753,  0.        ,  0.        ,  0.        ,  0.04861376,
#          0.14584129,  0.29168258,  0.3889101 ,  0.48613763,  0.43752387,
#          0.19445505,  0.24306882,  0.43752387,  0.29168258,  0.09722753,
#          0.19445505,  0.19445505,  0.14584129,  0.09722753,  0.09722753]),
#  array([-2.81733275, -2.56020392, -2.30307509, -2.04594626, -1.78881743,
#         -1.5316886 , -1.27455977, -1.01743094, -0.76030211, -0.50317328,
#         -0.24604446,  0.01108437,  0.2682132 ,  0.52534203,  0.78247086,
#          1.03959969,  1.29672852,  1.55385735,  1.81098618,  2.06811501,
#          2.32524384]),
#  <a list of 20 Patch objects>)

# %%
d1= randn(1000)
d2=randn(1000)

# %%
sns.jointplot(d1,d2)

# %%
sns.jointplot(d1,d2, kind='hex')

# %%
d= randn(100)

# %%
sns.distplot(d,bins=25)

# %%
sns.distplot(d,bins=25,rug=True, hist=False)

# %%
data1= randn(100)
data2=randn(100)

# %%
sns.boxplot(data1)

# %%
data1=stats.norm(0,5).rvs(100)

# %%
tip= sns.load_dataset('tips')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot('total_bill','tip',tip)  #linear regression plot

# %%
sns.lmplot('total_bill','tip',tip,
          scatter_kws={'marker':'o','color':'indianred'},
          line_kws={'linewidth':1,'color':'blue'})
